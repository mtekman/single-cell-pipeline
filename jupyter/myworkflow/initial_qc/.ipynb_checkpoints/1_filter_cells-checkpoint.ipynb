# %%
generate_matrix = T
source("load_matrix.R")

# We have the sce object, scater, and singlecellexperiment, fully annotated
# Out:
# Loading required package: SummarizedExperiment
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
# ...

# %% [markdown]
# # Filtering (Cell QC)
#
# ## Strategies
#
# ### There are two approaches:
#   1. Filter based on individual gene transcript counts within each cell
#   OR
#   2. Filter based on total transcripts discovered in a cell.
#
# ### Contending Issues
#   * Different cells were loaded across two different plates
#   * Different cells might have different systematic variations that could give false signal.
#
#
# ### Approaches
#   1. If we filter based on (1), then we remove any lowly expressed genes, but ignore any cell-to-cell bias that may exist
#   OR
#   2. If we filter based on (2), then we assess the quality of each cell as a whole first before determining whether a gene is suitable for analysis or not.
#
# ### Summary
#
#  * Filtering on 2 makes the most sense, since a low quality cell is more likely to exhibit a lower UMI counts in general, and may confound the analysis by creating variation only by course of being unhealthy, and NOT informative towards biological signal.
#
#  * Indeed, in the hemberg-lab workflow -- we can see that they filter for cells first, and then genes.
#
#
# ## Assessing cell quality
#
#  The approach taken by the hemberg group was to filter out any cells with a total count less than 25000, however they work with a much higher sequencing depth which nicely models a negative binomial distribution
#
#  ![their_histo](https://hemberg-lab.github.io/scRNA.seq.course/14-exprs-qc_files/figure-html/total-counts-hist-1.png)
#
#  ![their_binom](https://hemberg-lab.github.io/scRNA.seq.course/29-de-intro_files/figure-html/nb-plot-1.png)

# %%
sce <- calculateQCMetrics(sce)
hist(sce$total_counts, breaks = 100)
abline(v = 25000, col = "red")

cells_filtered_hem <- dim(sce[,colSums(counts(sce)) > 25000])[[2]]
cells_filtered_hem
# Out:
# [1] 62
# Plot with title “Histogram of sce$total_counts”

# %% [markdown]
# However, our data has much lower coverage and we would keep only 62 (32%) of our cells if we filtered at this level. The profile of our counts also follows a zero-inflated binomial distribution model.
#
#   ![our_distr](https://hemberg-lab.github.io/scRNA.seq.course/29-de-intro_files/figure-html/zero-inflation-plot-1.png)
#
# It is clear that we cannot use the same 25000 umi threshold that they do, but **we must explore to see which thresholds best suit our data.**

# %%
hist(sce$total_counts, breaks = 100)

table <- data.frame()
ranges_c <- append(c(1,100,500,1000,2000,4000,6000), seq(8000,26000,2000))
colors_c <- scales::seq_gradient_pal("blue", "red", "Lab")(seq(0,1,length.out=length(ranges_c)))


feature_table <- data.frame()

it = 0
for (thresh in ranges_c){
    it = it + 1    
    new_sce <- sce[,colSums(counts(sce)) > thresh]
    
    cells_left <- dim(new_sce)[[2]]    
    
    table <- rbind(table, c(thresh, 100 * cells_left / dim(sce)[[2]]))    
    feature_table <- rbind(feature_table, cbind( c(thresh), new_sce$total_features))
    
    abline(v=thresh, col=colors_c[[it]])
}

names(table) <- c("SeqThreshold", "CellsLeft")
names(feature_table) <- c("SeqThreshold", "AllExprValues")
# Out:
# Plot with title “Histogram of sce$total_counts”

# %% [markdown]
#    The above histogram shows the threshold cutoff points, where all cells with total counts above the threshold are kept.
#
#    Below we will determine which is the best threshold by examining the overall variation in gene expression values at each cut off and finding the most "even" under the constraint of maximising the number of cells still left in our data set.
#
# ### Autodetecting sequencing depth cut-off
#
#  1. Compute gene count boxplot stats and determine 'eveness' by the proportion of sizes between the median and the 1st and 3rd quartiles. This will produce a "table of eveness" which shows all thresholds that fall within an acceptable limit of  `1 - flex < x < 1 + flex` where `flex` is a user-set threshold of ~ 0.2

# %%
flex = 0.2

feature_summary <- data.frame()

for (thresh in ranges_c){
    tab <- list()
    tab[c("min","q1","med","mean","q3","max")] <- unname(summary(
        feature_table[feature_table$SeqThreshold==thresh,]$AllExprValue
    ))
       
    feature_summary <- rbind(feature_summary, c(
        thresh, 
        tab$min, tab$max, tab$med, tab$mean, 
        tab$q1, tab$q3, (tab$q3 - tab$med) / (tab$med - tab$q1)
        #tab$q3 - tab$q1
    ))   
}

colnames(feature_summary) <- c("Thresh", "Min", "Max", "Median", "Mean", "Q1", "Q3", "Q3-Median / Median-Q1")


table_of_evenness <- feature_summary[
    (1 - flex) < feature_summary[[8]]  &   feature_summary[[8]] < (1 + flex),
]
message("Table of Evenness")
table_of_evenness

# Extract the first Threshold within the table of eveness.
best_thresh <- table_of_evenness[1,]$Thresh
perc_cells <- 100 * dim(sce[,colSums(counts(sce)) > best_thresh])[[2]] / dim(sce)[[2]]



ggplot(feature_table, aes(x = factor(SeqThreshold), y = AllExprValues, group =SeqThreshold)
) + geom_boxplot(notch=T, outlier.shape = NA, fill = "red", alpha = 0.2,
) + geom_boxplot(notch=T, 
                 data=feature_table[feature_table$SeqThresh==best_thresh,], 
                 fill="red"
) + geom_vline(xintercept=c(best_thresh), col = "red", alpha = 0.7, linetype="dotted"
) + xlab("Sequencing Depth"
) + ylab("Gene expression values"
)


ggplot(table, aes(x=SeqThreshold, y=CellsLeft)
) + geom_vline(xintercept=best_thresh, col = "red", alpha = 0.7, linetype="dotted"
) + geom_hline(yintercept=perc_cells, col = "red", alpha = 0.7, linetype="dotted"
) + geom_line(
) + xlab("Sequencing Depth"
) + ylab("Number of cells left (%)"
) + scale_x_continuous(breaks = seq(0, max(table$SeqThreshold), 2000)
) + scale_y_continuous(breaks = seq(0,100,10)
) + annotate("text", x = best_thresh + 10000, y=perc_cells + 0.7, 
             label = "threshold of evenness", color = "red", size = 3, alpha = 0.7)



#message(table[table$SeqThreshold == 6000,][[2]])
#dim(sce[,colSums(counts(sce)) > 6000])[[2]]
# Out:
# Table of Evenness
#    Thresh Min  Max  Median Mean     Q1     Q3      Q3-Median / Median-Q1
# 7   6000  2473 9069 5796.5 5661.379 4744.0 6722.75 0.8800475
# 8   8000  3306 9069 5892.0 5919.562 5060.0 6746.00 1.0264423
# 9  10000  3447 9069 5921.5 6024.759 5125.5 6813.00 1.1199749
# 10 12000  4138 9069 6046.0 6124.838 5184.5 6956.50 1.0568775
# 13 18000  5060 9069 6400.0 6464.626 5760.0 7045.00 1.0078125
# 14 20000  5120 9069 6519.0 6614.864 5892.0 7169.00 1.0366826
# 16 24000  5557 9069 6718.0 6848.308 6190.0 7340.00 1.1780303
# plot without title
# plot without title

# %% [markdown]
#    From this we can see that the variation in our global expression levels becomes less tail-heavy at a sequencing depth of ~ 6000. At this level, we can still retain 68.75% (132) of our cells.

# %%
message("Saving filtered matrix")
saveRDS(sce[,colSums(counts(sce)) > best_thresh], "matrix.cellQC.rds")
# Out:
# Saving filtered matrix
