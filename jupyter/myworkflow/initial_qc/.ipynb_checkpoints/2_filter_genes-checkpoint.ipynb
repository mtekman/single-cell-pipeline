# %%
## Assessing the quality of the genes in our remaining cells
generate_matrix = F
matrix_destination = "matrix.cellQC.rds"
source("load_matrix.R")
# Out:
# Loading matrix from source file matrix.cellQC.rds...
# 21070 genes x 132 cells. (132) unique barcodes.

# %% [markdown]
# ## Filter Genes
#
# If we were to plot the total number of (non-zero) genes per cell in a histogram, we would expect a normal distribution with long tails.
#
# For high-seq depth, we would see something like this
#
#  ![hemb_feat](https://hemberg-lab.github.io/scRNA.seq.course/14-exprs-qc_files/figure-html/total-features-hist-1.png)
#
#  where a minimum cut-off line of 7000 genes is set to remove the cells with smaller gene libraries that are likely indicative of poor quality cells.
#
# For low-seq depth data, such as what *we* are dealing with, our distribution looks like this:

# %%
hist(sce$total_features, breaks=70)
abline(v = 7000, col = "red")

table(sce$total_features > 7000)
# Out:
# FALSE  TRUE
#   106    26
# Plot with title “Histogram of sce$total_features”

# %% [markdown]
# where just by applying the same threshold we would be left with only 13 cells. Note also that the high variability in the "distribution" due to there being only 192 cells in total.
#
# Regardless of how noisy it appears, there may still be a signal to explore at more acceptable threshold.
#
#
# #### Contending Issues: Gene Detectability
#
#  1. Some genes may only exist in cells at low counts. This could mean very low expression, but we must filter above a noise threshold to determine significance. Filtering by this could produce a row of zeroes depending upon if we filter by:
#
#    * **Individual cell-basis:** We zero-out only the individual transcript counts for specific cells if below a minumum expected threshold.
#    * **Overall gene-bases:** We zero-out a whole gene if the total transcript counts across all cells are below a minumum expected threshold.
#
#  2. Some genes that are known to exist in the source sample are simply not detected by the sequencing platform ("allelic drop-outs"). These often result in a row of zeroes and must be removed since there is no useful comparison that can be derived from them.
#
#  3. Some genes only exist in only a limited number of cells. Depending on how high the number of UMI counts, they could be significant genes that outline rare cell types, or they could just be noise. We must determine a good minimum threshold of cells that our genes should be expressed by
#
# #### Aims
#
#  * Find a threshold of significance for the lowest number of cells that a gene can appear in.
#  * Find a threshold of significance for the lowest number of observeable counts for a gene:
#      * Cell-by-cell basis
#      * Overall gene basis
#
# ##### Notes:
#
#  * sce\$total_counts -- is total counts per cell
#  * sce\$total_features -- is total genes per cell (or number of non-zero counts per cell)

# %% [markdown]
#  First let us look at the quality of the annotations that our gene transcripts have to find any inconsistencies

# %%
message(sprintf("We have %5.0f     ENSMUS IDs, of which %5.0f are unique.",
    length(names(sce)), length(unique(sort(names(sce))))
))

message(sprintf("We have %5.0f       Gene IDs, of which %5.0f are unique.",
                length(rowData(sce)$external_gene_name), 
                length(unique(sort(rowData(sce)$external_gene_name)))
))

message(sprintf("We have %5.0f Transcript IDs, of which %5.0f are unique.",
                length(rowData(sce)$external_transcript_name),
                length(unique(sort(rowData(sce)$external_transcript_name)))
))
# Out:
# We have 21070     ENSMUS IDs, of which 21048 are unique.
# We have 21070       Gene IDs, of which 21041 are unique.
# We have 21070 Transcript IDs, of which 21048 are unique.

# %% [markdown]
# There appears to be a discrepancy of 22 transcripts. Let us examine them.

# %%
library(data.table)
vec <- rowData(sce)$external_transcript_name
filter_duplicates <- rownames(sce) %in% names(
    sce[duplicated(vec) | duplicated(vec, fromLast=TRUE),]
)

# Table of the culprits
fair <- rowData(sce[filter_duplicates,])
name_fair <- names(fair)

mat <- matrix(unlist(fair), ncol=length(name_fair))
colnames(mat) <- names(fair)
mat <- data.frame(mat)

out_table <- data.table(mat)
out_table <- out_table[,c(9,1,16)]
colnames(out_table) <- c("Ensemble_89", "Ensemble_91", "Total_Counts")
out_table
# Out:
#    Ensemble_89        Ensemble_91 Total_Counts
# 1  ENSMUSG00000045713 NA          1
# 2  ENSMUSG00000071567 NA          1
# 3  ENSMUSG00000079489 NA          6
# 4  ENSMUSG00000090286 NA          5
# 5  ENSMUSG00000093501 NA          1
# 6  ENSMUSG00000093561 NA          3
# 7  ENSMUSG00000093760 NA          1
# 8  ENSMUSG00000094114 NA          8
# 9  ENSMUSG00000094518 NA          22
# 10 ENSMUSG00000095367 NA          2
# 11 ENSMUSG00000095709 NA          2
# 12 ENSMUSG00000096789 NA          1
# 13 ENSMUSG00000096807 NA          1
# 14 ENSMUSG00000097102 NA          3
# 15 ENSMUSG00000102171 NA          19
# 16 ENSMUSG00000102306 NA          2
# 17 ENSMUSG00000103283 NA          17
# 18 ENSMUSG00000104056 NA          1
# 19 ENSMUSG00000104389 NA          20
# 20 ENSMUSG00000110859 NA          1
# 21 ENSMUSG00000114116 NA          3
# 22 ENSMUSG00000114146 NA          6

# %% [markdown]
# These genes are very poorly expressed, with no more than 22 total counts across all cells.
#
# A look through the ensembl database reveals also that all of these genes have been retired:

# %%
getexpr = function(s,g){substring(s,g,g+attr(g,'match.length')-1)}
matcher <- '<div class="lhs">Status</div><div class="rhs"><p>([^<]*)</p>'

checkStatus <- function(rname){
    
    url_name <- paste(
        'http://www.ensembl.org/Mus_musculus/Gene/Idhistory?g=', rname,
        sep=""
    )
    page <- readLines(url_name)
    
    datalines <- grep(matcher, page, value=T)
    gg = gregexpr(matcher,datalines)
    matches = mapply(getexpr,datalines,gg)
    result = gsub(matcher,'\\1',matches)
    names(result) = NULL

    return(result)
}

alleg <- list()
for (ENS in fair$feature_id){
    alleg <- rbind(alleg, c(ENS, checkStatus(ENS)))
}
colnames(alleg) <- c("Gene", "Status")
alleg

# %% [markdown]
# We should remove these genes from the analysis if we wish to make sense of our data.

# %%
# Remove the low-covered genes
sce2 <- sce[(!(rowData(sce)$ensembl_gene_id %in% mat[order(mat$external_gene_name),]$ensembl_gene_id)),]

# Remove other genes with less than 20 counts
sce2 <- sce2[rowSums(counts(sce2)) > 20,]

tab <- rbind(dim(sce), dim(sce2))
rownames(tab) <- c("Row counts >= 0", "Row counts > 20")
colnames(tab) <- c("Num Genes", "Num Cells")
tab
#plotQC(sce2, type="high")
# Out:
#                 Num Genes Num Cells
# Row counts >= 0 21070     132
# Row counts > 20  9741     132

# %% [markdown]
#  This act of filtering *just* 20 **total** counts for a gene has discarded more than half of our dataset...!
#
#  Let us explore this threshold more.

# %%
hist(sce$total_features, breaks = 100)
#hist(sce$total_features, breaks = 100, col = "red", add = T)
# Out:
# Plot with title “Histogram of sce$total_features”

# %%
sce <- calculateQCMetrics(sce2)

# We wish to remove cells that only express 2 or more genes
#dim(sce)

message(dim(sce)[[2]], " cells (raw)")

min_genes <- c(1,2,3,4,5,10,20,30)
min_seq <- append(c(1,10,20,50,70,80), seq(100,800,50), c(25000))

#outer(min_genes, min_seq, function(g,s){sum(colSums(counts(sce) >= s) >= g)})

table <- data.frame()

for (g in min_genes){
    for (s in min_seq){
        cells <- sum(colSums(counts(sce) >= s) >= g)
        table <- rbind(table, c(s, g, cells))      
        message(sprintf("%4.0f cells with >= %5.0f seq-depth and >= %3.0f genes", cells, s, g))
    }
}
colnames(table) <- c("seqdepth", "genes", "cells")
# Out:
# 132 cells (raw)
#  132 cells with >=     1 seq-depth and >=   1 genes
#  132 cells with >=    10 seq-depth and >=   1 genes
#  132 cells with >=    20 seq-depth and >=   1 genes
#  132 cells with >=    50 seq-depth and >=   1 genes
#  131 cells with >=    70 seq-depth and >=   1 genes
#  130 cells with >=    80 seq-depth and >=   1 genes
#  128 cells with >=   100 seq-depth and >=   1 genes
#  120 cells with >=   150 seq-depth and >=   1 genes
#  107 cells with >=   200 seq-depth and >=   1 genes
#   95 cells with >=   250 seq-depth and >=   1 genes
#   82 cells with >=   300 seq-depth and >=   1 genes
#   66 cells with >=   350 seq-depth and >=   1 genes
#   47 cells with >=   400 seq-depth and >=   1 genes
#   31 cells with >=   450 seq-depth and >=   1 genes
#   18 cells with >=   500 seq-depth and >=   1 genes
#   10 cells with >=   550 seq-depth and >=   1 genes
#    7 cells with >=   600 seq-depth and >=   1 genes
#    5 cells with >=   650 seq-depth and >=   1 genes
#    1 cells with >=   700 seq-depth and >=   1 genes
#    0 cells with >=   750 seq-depth and >=   1 genes
#    0 cells with >=   800 seq-depth and >=   1 genes
#  132 cells with >=     1 seq-depth and >=   2 genes
#  132 cells with >=    10 seq-depth and >=   2 genes
#  132 cells with >=    20 seq-depth and >=   2 genes
#  132 cells with >=    50 seq-depth and >=   2 genes
#  129 cells with >=    70 seq-depth and >=   2 genes
#  128 cells with >=    80 seq-depth and >=   2 genes
#  125 cells with >=   100 seq-depth and >=   2 genes
#  108 cells with >=   150 seq-depth and >=   2 genes
#   84 cells with >=   200 seq-depth and >=   2 genes
#   66 cells with >=   250 seq-depth and >=   2 genes
#   38 cells with >=   300 seq-depth and >=   2 genes
#   16 cells with >=   350 seq-depth and >=   2 genes
#   10 cells with >=   400 seq-depth and >=   2 genes
#    0 cells with >=   450 seq-depth and >=   2 genes
#    0 cells with >=   500 seq-depth and >=   2 genes
#    0 cells with >=   550 seq-depth and >=   2 genes
#    0 cells with >=   600 seq-depth and >=   2 genes
#    0 cells with >=   650 seq-depth and >=   2 genes
#    0 cells with >=   700 seq-depth and >=   2 genes
#    0 cells with >=   750 seq-depth and >=   2 genes
#    0 cells with >=   800 seq-depth and >=   2 genes
#  132 cells with >=     1 seq-depth and >=   3 genes
#  132 cells with >=    10 seq-depth and >=   3 genes
#  132 cells with >=    20 seq-depth and >=   3 genes
#  131 cells with >=    50 seq-depth and >=   3 genes
#  128 cells with >=    70 seq-depth and >=   3 genes
#  125 cells with >=    80 seq-depth and >=   3 genes
#  122 cells with >=   100 seq-depth and >=   3 genes
#   93 cells with >=   150 seq-depth and >=   3 genes
#   67 cells with >=   200 seq-depth and >=   3 genes
#   50 cells with >=   250 seq-depth and >=   3 genes
#   18 cells with >=   300 seq-depth and >=   3 genes
#    8 cells with >=   350 seq-depth and >=   3 genes
#    0 cells with >=   400 seq-depth and >=   3 genes
#    0 cells with >=   450 seq-depth and >=   3 genes
#    0 cells with >=   500 seq-depth and >=   3 genes
#    0 cells with >=   550 seq-depth and >=   3 genes
#    0 cells with >=   600 seq-depth and >=   3 genes
#    0 cells with >=   650 seq-depth and >=   3 genes
#    0 cells with >=   700 seq-depth and >=   3 genes
#    0 cells with >=   750 seq-depth and >=   3 genes
#    0 cells with >=   800 seq-depth and >=   3 genes
#  132 cells with >=     1 seq-depth and >=   4 genes
#  132 cells with >=    10 seq-depth and >=   4 genes
#  132 cells with >=    20 seq-depth and >=   4 genes
#  130 cells with >=    50 seq-depth and >=   4 genes
#  125 cells with >=    70 seq-depth and >=   4 genes
#  124 cells with >=    80 seq-depth and >=   4 genes
#  115 cells with >=   100 seq-depth and >=   4 genes
#   87 cells with >=   150 seq-depth and >=   4 genes
#   56 cells with >=   200 seq-depth and >=   4 genes
#   26 cells with >=   250 seq-depth and >=   4 genes
#   11 cells with >=   300 seq-depth and >=   4 genes
#    4 cells with >=   350 seq-depth and >=   4 genes
#    0 cells with >=   400 seq-depth and >=   4 genes
#    0 cells with >=   450 seq-depth and >=   4 genes
#    0 cells with >=   500 seq-depth and >=   4 genes
#    0 cells with >=   550 seq-depth and >=   4 genes
#    0 cells with >=   600 seq-depth and >=   4 genes
#    0 cells with >=   650 seq-depth and >=   4 genes
#    0 cells with >=   700 seq-depth and >=   4 genes
#    0 cells with >=   750 seq-depth and >=   4 genes
#    0 cells with >=   800 seq-depth and >=   4 genes
#  132 cells with >=     1 seq-depth and >=   5 genes
#  132 cells with >=    10 seq-depth and >=   5 genes
#  132 cells with >=    20 seq-depth and >=   5 genes
#  129 cells with >=    50 seq-depth and >=   5 genes
#  125 cells with >=    70 seq-depth and >=   5 genes
#  121 cells with >=    80 seq-depth and >=   5 genes
#  112 cells with >=   100 seq-depth and >=   5 genes
#   76 cells with >=   150 seq-depth and >=   5 genes
#   46 cells with >=   200 seq-depth and >=   5 genes
#   14 cells with >=   250 seq-depth and >=   5 genes
#    4 cells with >=   300 seq-depth and >=   5 genes
#    0 cells with >=   350 seq-depth and >=   5 genes
#    0 cells with >=   400 seq-depth and >=   5 genes
#    0 cells with >=   450 seq-depth and >=   5 genes
#    0 cells with >=   500 seq-depth and >=   5 genes
#    0 cells with >=   550 seq-depth and >=   5 genes
#    0 cells with >=   600 seq-depth and >=   5 genes
#    0 cells with >=   650 seq-depth and >=   5 genes
#    0 cells with >=   700 seq-depth and >=   5 genes
#    0 cells with >=   750 seq-depth and >=   5 genes
#    0 cells with >=   800 seq-depth and >=   5 genes
#  132 cells with >=     1 seq-depth and >=  10 genes
#  132 cells with >=    10 seq-depth and >=  10 genes
#  132 cells with >=    20 seq-depth and >=  10 genes
#  123 cells with >=    50 seq-depth and >=  10 genes
#  109 cells with >=    70 seq-depth and >=  10 genes
#   99 cells with >=    80 seq-depth and >=  10 genes
#   67 cells with >=   100 seq-depth and >=  10 genes
#   20 cells with >=   150 seq-depth and >=  10 genes
#    1 cells with >=   200 seq-depth and >=  10 genes
#    0 cells with >=   250 seq-depth and >=  10 genes
#    0 cells with >=   300 seq-depth and >=  10 genes
#    0 cells with >=   350 seq-depth and >=  10 genes
#    0 cells with >=   400 seq-depth and >=  10 genes
#    0 cells with >=   450 seq-depth and >=  10 genes
#    0 cells with >=   500 seq-depth and >=  10 genes
#    0 cells with >=   550 seq-depth and >=  10 genes
#    0 cells with >=   600 seq-depth and >=  10 genes
#    0 cells with >=   650 seq-depth and >=  10 genes
#    0 cells with >=   700 seq-depth and >=  10 genes
#    0 cells with >=   750 seq-depth and >=  10 genes
#    0 cells with >=   800 seq-depth and >=  10 genes
#  132 cells with >=     1 seq-depth and >=  20 genes
#  132 cells with >=    10 seq-depth and >=  20 genes
#  132 cells with >=    20 seq-depth and >=  20 genes
#   99 cells with >=    50 seq-depth and >=  20 genes
#   67 cells with >=    70 seq-depth and >=  20 genes
#   55 cells with >=    80 seq-depth and >=  20 genes
#   31 cells with >=   100 seq-depth and >=  20 genes
#    1 cells with >=   150 seq-depth and >=  20 genes
#    0 cells with >=   200 seq-depth and >=  20 genes
#    0 cells with >=   250 seq-depth and >=  20 genes
#    0 cells with >=   300 seq-depth and >=  20 genes
#    0 cells with >=   350 seq-depth and >=  20 genes
#    0 cells with >=   400 seq-depth and >=  20 genes
#    0 cells with >=   450 seq-depth and >=  20 genes
#    0 cells with >=   500 seq-depth and >=  20 genes
#    0 cells with >=   550 seq-depth and >=  20 genes
#    0 cells with >=   600 seq-depth and >=  20 genes
#    0 cells with >=   650 seq-depth and >=  20 genes
#    0 cells with >=   700 seq-depth and >=  20 genes
#    0 cells with >=   750 seq-depth and >=  20 genes
#    0 cells with >=   800 seq-depth and >=  20 genes
#  132 cells with >=     1 seq-depth and >=  30 genes
#  132 cells with >=    10 seq-depth and >=  30 genes
#  124 cells with >=    20 seq-depth and >=  30 genes
#   74 cells with >=    50 seq-depth and >=  30 genes
#   38 cells with >=    70 seq-depth and >=  30 genes
#   24 cells with >=    80 seq-depth and >=  30 genes
#   10 cells with >=   100 seq-depth and >=  30 genes
#    0 cells with >=   150 seq-depth and >=  30 genes
#    0 cells with >=   200 seq-depth and >=  30 genes
#    0 cells with >=   250 seq-depth and >=  30 genes
#    0 cells with >=   300 seq-depth and >=  30 genes
#    0 cells with >=   350 seq-depth and >=  30 genes
#    0 cells with >=   400 seq-depth and >=  30 genes
#    0 cells with >=   450 seq-depth and >=  30 genes
#    0 cells with >=   500 seq-depth and >=  30 genes
#    0 cells with >=   550 seq-depth and >=  30 genes
#    0 cells with >=   600 seq-depth and >=  30 genes
#    0 cells with >=   650 seq-depth and >=  30 genes
#    0 cells with >=   700 seq-depth and >=  30 genes
#    0 cells with >=   750 seq-depth and >=  30 genes
#    0 cells with >=   800 seq-depth and >=  30 genes

# %%
ggplot(table, aes(x=seqdepth, y=cells, group=genes)) + geom_line(
    aes(colour=genes)
) + scale_colour_gradientn(colours = terrain.colors(10)
                          ) + xlab("Sequencing Depth") + ylab("Number of cells")


plotQC(sce, type="high")
# Out:
# plot without title
# plot without title

# %%
hist(
    sce$total_counts,
    breaks = 100
)
abline(v=25000)
