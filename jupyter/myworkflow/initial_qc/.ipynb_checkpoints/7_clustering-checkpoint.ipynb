# %%
IRdisplay::display_html('
<style>
div.output_scroll {height: 45em }
</style>
')
# Out:
# <style>
# div.output_scroll {height: 45em }
# </style>

# %%
matrix_destination = "matrix.cellQC.geneQC.normalised.hk_controls.ccClean.combat.rds"
source("load_matrix.R")
# Out:
# Loading required package: SummarizedExperiment
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
# ...

# %% [markdown]
# # Clustering
#
# Now that our data is filtered, normalised, cleaned of cell-cycle variations, and free from technical artefacts, we will attempt to perform cell-type clustering.

# %%
suppressWarnings(library(SC3))

# %% [markdown]
# ## SC3
#
# We will use the SC3 libary which combines heirarchal clustering and k-means. It operates by making an inital estimate on the number of clusters (*k*), and then iterates through different levels of k (encompassing the estimated) to determine a stable value of k which should results in the most optimal clustering

# %%
# Estimate
sce <- sc3_estimate_k(sce)

# Write feature names to feature_symbol
rowData(sce)$feature_symbol = rownames(sce)       # must connect this slot for SC3
message("Best guess on the number of clusters: ", metadata(sce)$sc3$k_estimation)
# Out:
# Estimating k...
# Best guess on the number of clusters: 2

# %% [markdown]
# Now we can run the SC3 analysis:

# %%
krange <- 2:10
sce <- sc3(sce, ks = krange, biology = TRUE)
# Out:
# Setting SC3 parameters...
# Calculating distances between the cells...
# Performing transformations and calculating eigenvectors...
# Performing k-means clustering...
# Calculating consensus matrix...
# Calculating biology...

# %% [markdown]
# With clustering finished, and a consensus matrix constructed, we can now attempt to plot our cells. Let us first observe the relative stability of each of the clusters defined for a specific *k*. A [higher stability](https://rdrr.io/bioc/SC3/man/calculate_stability.html) index, a higher chance that the same clustering appears in other values of k.

# %%
sc3_plot_cluster_stability(sce, tail(krange, n=1))
# Out:
# plot without title

# %%
library(gridExtra)

#multiplot(    # doesn't work for sc3

cat("Plots\n")
for (k in krange){   
    sc3_plot_consensus(sce, k)
    cat(sprintf("k = %.0f\n", k))
}
# Out:
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     combine
# Plots
# k = 2
# plot without title
# k = 3
# plot without title
# k = 4
# plot without title
# k = 5
# plot without title
# k = 6
# plot without title
# k = 7
# plot without title
# k = 8
# plot without title
# k = 9
# plot without title
# k = 10
# plot without title

# %% [markdown]
# We see some pretty neat groups at earlier k's, and potentially complicated sub-types at the later k's:
#   * k = 2 and k = 3, shows strong contrasts between each of the defined clusters
#   * k = 4, structure breaks down with only two main clusters showing strong similarity, and two smaller clusters which share ~ 0.5 similiratity with the larger two.
#   * k = 5,  we see only one tiny well defined clusted (top left)
#   * k = 6, the four largest clusters seem to show some similarity to one another and stark dissimilarity to the smallest two
#   * k = 7, one large reasonably well-defined cluster
#   * k = 8, 6 reasonablly well defined clusters

# %%
for (k in krange){
    sc3_plot_silhouette(sce, k)
}
# Out:
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”
# Plot with title “Silhouette plot of (x = clusts, dist = diss)”

# %% [markdown]
#  * At k = 2 or 3, most cells are assigned to their cluster with a high score (> 0.8)
#  * At k = 4, only the cells in two small clusters have a high score, and the cells in cluster 3 have a reasonable score (> 0.6), but the cells in cluster 4 are not very similar to one another.
#  * At k = 5, the maximum high score has dropped, but we see a better overall score in all clusters (as well as some outliers)
#  * At k = 6, most clusters are reasonably-defined with an exception of cluster 6, and a few outliers in cluster 4.
#  * At k = 7, the scores appear to have improved to be between reasonable and high in all groups, and though there are (very extreme) outliers in each group, they appear to be very few.
#  * At k = 8 to 10, we see a drop in at least 2 or 3 clusters beyond the point of reasonable socring.

# %%
for (k in krange){
    sc3_plot_expression(sce, k)
    cat(sprintf("k = %.0f\n", k))
}
# Out:
# k = 2
# plot without title
# k = 3
# plot without title
# k = 4
# plot without title
# k = 5
# plot without title
# k = 6
# plot without title
# k = 7
# plot without title
# k = 8
# plot without title
# k = 9
# plot without title
# k = 10
# plot without title

# %% [markdown]
# These matrices are hard to interpret, the overall expression seems pretty weak except for a few small instances

# %%
for (i in krange){
    try(
        sc3_plot_markers(sce, i, 0, 1),
        silent = F
    )
    cat(sprintf("k = %.0f\n", i))
}

infoTable <- function(names)
{
    tableau <- list()
    
    for (name in names){
        tableau <- rbind(tableau, c(
            rowData(sce[rownames(sce) %in% name,])$external_transcript_name[[1]],
            rowData(sce[rownames(sce) %in% name,])$description[[1]]
        ))
    }
    
    if (length(tableau) > 0){    
        colnames(tableau) <- c("Gene Name", "Description")
    }
    return(tableau)
}
#sc3_plot_markers(sce, 7, 0, 1)
# Out:
# k = 2
# plot without title
# k = 3
# plot without title
# k = 4
# plot without title
# k = 5
# plot without title
# k = 6
# plot without title
# k = 7
# plot without title
# k = 8
# plot without title
# k = 9
# plot without title
# k = 10
# plot without title

# %%
infoTable(c("Ankrd26-201"))
# Out:
#      Gene Name   Description
# [1,] Ankrd26-201 ankyrin repeat domain 26 [Source:MGI Symbol;Acc:MGI:1917887]

# %% [markdown]
# The expression heatmap appears to not give any distinct gene expression for a cluster, with the exception of Ankrd26, whose relevance to defining a given cell-type is somewhat dubious given that it has

# %% [markdown]
# In our next step we will use these computed clusters upon some PCA (and/or TSNE) plots to see how well the clusters fit the data.
#
# The main facet of these results appear to be defined primarily by whether Ankrd26 expression is specific to any cell type or not. A quick look at the functional annotations of the gene yields a gene that is active in cytoskeleten and non-membrane-bounded organelles.
#
#  ![biom](imgs/ankrd26.png)
#  ![biom](imgs/ankrd26-1.png)

# %%
#names(rowData(sce))
#sum(!is.na(rowData(sce)$go_id))
#rowData(sce)$go_linkage_type
#rowData(sce)$name_1006
#rowData(sce)$definition_1006
#rowData(sce)$namespace_1003
#infoTable(c("Ankrd26-201"))

# %%
saveRDS(sce, "matrix.cellQC.geneQC.normalised.ccClean.combat.sc3_clust.rds")
